# %% [markdown]
# # PARSER
# ## read all JSON files of a given time period and parse them into the database
#
# ### TODO: bikes taken at 0:00, bikes and stations in database if not yet existent, no ride if API unavailable

# %%
# GET BIKES FROM DATABASE

from mysql.connector import connect, Error
from getpass import getpass
from datetime import date
from datetime import datetime
import requests
import os, os.path, datetime, json
from json.decoder import JSONDecodeError
import pprint
import math

# create MySQL connection
connection = connect(
        host="localhost",
        user="root",
        password=getpass("Enter password: "),
        database="bikes",
    )
connection.autocommit = True
cursor = connection.cursor()
cursor.execute("SELECT bike_id FROM bike WHERE provider = 'callabike'")

start_datetime = datetime.datetime.strptime('2021-06-04-00-00', '%Y-%m-%d-%H-%M')
end_datetime = datetime.datetime.strptime('2021-06-18-23-59', '%Y-%m-%d-%H-%M')
previous_minute_datetime = start_datetime - datetime.timedelta(minutes=1)

callabike_bike_status_dict = {}
callabike_bike_status_dict = {bike[0]:list() for bike in cursor.fetchall()}
cursor.execute("SELECT bike_id, ST_Y(coordinates), ST_X(coordinates), station_id, since FROM bike_last_status NATURAL JOIN bike WHERE provider='callabike'")
for bike_last_status in cursor.fetchall():
    # concatenate coordinates to call-a-bike json format (will be compared with json later)
    coordinates = '[' + str(bike_last_status[1]) + ', ' + str(bike_last_status[2]) + ']'
    station_id = bike_last_status[3]
    # since = datetime.datetime.strptime(unfinished_ride[4], '%Y/%m/%d %H:%M:%S')
    since = bike_last_status[4]
    callabike_bike_status_dict[bike_last_status[0]] = [coordinates, station_id, since]
for bike in callabike_bike_status_dict.values():
    if not bike: # if list within bike is empty
        bike[:] = ['no_ride', '', previous_minute_datetime]
# print(callabike_bike_status_dict)

# list for bikes that do not exist yet (not set as list is required for SQL insertion)
callabike_new_bikes_list = []

# %%
def getAndInsertNewStations():
    
    # get IDs of all existing stations and save in new set
    cursor.execute("SELECT station_id FROM station WHERE provider='callabike'")
    callabike_stations_set = {station[0] for station in cursor.fetchall()}
    
    # list for stations that do not exist yet
    callabike_new_stations_list = list()

    DIR = 'json/Stations'

    # get current Call-A-Bike station JSON with 10km radius around mid-Berlin
    lat = "&lat=52.518611"
    lon = "&lon=13.408333"
    radius = "&radius=10000"
    limit = "&limit=100"
    url = "https://api.deutschebahn.com/flinkster-api-ng/v1/areas?providernetwork=2" + lat + lon + radius + limit
    headers = {
        'Accept': 'application/json',
        'Authorization': 'Bearer 56b6c4f18d92c4869078102e978ec8b9',
    }

    resp = requests.get(url, headers=headers)
    # get number of available stations, divide by 100 and round up to get number of necessary requests
    requests_no = math.ceil(resp.json()['size'] / 100)
    # save first 100 stations
    with open(DIR+'/callabike_station_0.json', 'wb') as f:
        f.write(resp.content)
    # start counting at 1 (first one already saved) until number of necessary requests reached
    for i in range(1, requests_no):
        # scroll through stations in steps of 100 by incrementally increasing offset (starting with 100)
        offset = "&offset=" + str(i*100)
        # request json with given offset
        url = "https://api.deutschebahn.com/flinkster-api-ng/v1/areas?providernetwork=2" + lat + lon + radius + offset + limit
        resp = requests.get(url, headers=headers)
        # save JSON with numbered filename in directory
        with open(DIR+'/callabike_station_'+str(i)+'.json', 'wb') as f:
            f.write(resp.content)


    # go through files 1 to 4
    for j in range(0, requests_no):
        try:
            with open(DIR+'/callabike_station_'+str(j)+'.json') as station_json:
                jsonObject = json.load(station_json)
                station_json.close()
            stations = jsonObject['items']
            # for every station 
            for station in stations:
                station_id =  station['uid']
                # if station doesn't exist in database yet
                if(station_id not in callabike_stations_set):
                    # retrieve station data and add to call-a-bike station list
                    station_latitude = str(station['geometry']['centroid']['coordinates'][1])
                    station_longitude = str(station['geometry']['centroid']['coordinates'][0])
                    # Format for MySQL ST_GeomFromText and SRID 4326: Point(52.53153 13.38651) -> in reverse order!
                    station_coordinates = 'Point(' + station_latitude + ' ' + station_longitude + ')'
                    station_name = station['name']
                    station_provider =  'callabike'
                    # station_capacity = ''
                    callabike_stations_set.add(station_id)
                    callabike_new_stations_list.append(list([station_id,station_coordinates,station_name,station_provider]))
        except Error as e:
            print('Error occured!')
    print('new stations: ')
    print(callabike_new_stations_list)
    cursor.executemany("INSERT INTO station (station_id, coordinates, name, provider) VALUES (%s,  ST_GeomFromText(%s, 4326), %s, %s) ON DUPLICATE KEY UPDATE station_id=station_id", callabike_new_stations_list)
    connection.commit()

# %%
def insertLastBikeStatus(callabike_bike_status_dict, last_datetime):
    last_bike_status_list = []
    for bike_id, bike in callabike_bike_status_dict.items():
        # if(bike[0] != 'no_ride' and bike[2] != datetime_current):
        if(bike[0] != 'no_ride'): # and bike[2] != last_datetime):
            coordinates_space_position = bike[0].index(", ")
            coordinates_Y = bike[0][1:coordinates_space_position]
            coordinates_X = bike[0][coordinates_space_position+2:-1]
            coordinates = 'POINT(' + coordinates_X + ' ' + coordinates_Y + ')'
            station = None if not bike[1] else bike[1]
            last_bike_status_list.append((bike_id, coordinates, station, str(bike[2])))
    # print(last_bike_status_list)

    cursor.execute("TRUNCATE TABLE bike_last_status")
    cursor.executemany("INSERT IGNORE INTO bike_last_status (bike_id, coordinates, station_id, since) VALUES (%s, ST_GeomFromText(%s, 4326), %s, %s)", last_bike_status_list)
    connection.commit()

# %%
def insertBikeRides(callabike_ride_list):

    ride_list = []
    for ride in callabike_ride_list:
        # if(ride[0] != 'no_ride' and ride[2] != datetime_current):
        if(ride[1] != 'no_ride'):
            bike_id = ride[0]
            start_coordinates_space_position = ride[1].index(", ")
            start_coordinates_Y = ride[1][1:start_coordinates_space_position]
            start_coordinates_X = ride[1][start_coordinates_space_position+2:-1]
            start_coordinates = 'POINT(' + start_coordinates_X + ' ' + start_coordinates_Y + ')'
            
            end_coordinates_space_position = ride[2].index(", ")
            end_coordinates_Y = ride[2][1:end_coordinates_space_position]
            end_coordinates_X = ride[2][end_coordinates_space_position+2:-1]
            end_coordinates = 'POINT(' + end_coordinates_X + ' ' + end_coordinates_Y + ')'

            start_station = None if not ride[3] else ride[3]
            end_station = None if not ride[4] else ride[4]

            ride_list.append((bike_id, start_coordinates, end_coordinates, start_station, end_station, str(ride[5]), str(ride[6])))
    # print(ride_list)

    cursor.executemany("INSERT INTO bike_ride (bike_id, start_coordinates, end_coordinates, start_station_id, end_station_id, since, until) VALUES (%s, ST_GeomFromText(%s, 4326), ST_GeomFromText(%s, 4326), %s, %s, %s, %s)", ride_list)
    connection.commit()

# %%
pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(callabike_actual_bike_rides_list)
# pp.pprint(callabike_bike_status_dict)

# %%
def insertExceptions(callabike_exceptions_dict):
    callabike_exceptions_list = [(value, key) for key, value in callabike_exception_dict.items()]
    pp.pprint(callabike_exceptions_list)
    cursor.executemany("INSERT INTO exception (provider, error_type, time) VALUES ('callabike', %s, %s)", callabike_exceptions_list)
    connection.commit()

# %%
def handleAPIException(error_type):
    timestamp_mysql = date + " " + f'{hour:02d}' + ':' + f'{minute:02d}'
    if(timestamp_mysql not in callabike_exception_dict):
        for bike in callabike_bike_status_dict.values():
            if(bike[2] == datetime_last_minute):
                bike[2] = datetime_current
        # print(timestamp_mysql + ': ' + error_type)
        callabike_exception_dict[timestamp_mysql] = error_type

# %%
# all stations found in callabike-15.json
def handleNotAllFilesException(missingFiles):
    callabike15_stations_list = ['E4816436351084C8665A14A791C92B9029FFE5A9', 'E53918D18D77DEC63E7617E6D576407B59A1CC64', 'E5F13D0D680098E71BCD58C24D50D2798DA105A2', 'E63983D1B9B421396BB47E084C48FF98D9F6541E', 'E7207FECDF4A6C2970B605043BD13509BC6E8BF2', 'E896DAE5C5C8641085D78F3454039BF11F88B490', 'E95B9D2D4BC6DFF1B4E4041EFA48B2E854F39F50', 'E985E95024AE08B95C5D02A99C243F3C12B21958', 'E9A4731FB1469854AF2EB04B46A20C06C7BDEFE0', 'E9C917B09D272FD073B8BAB13AFE3949D3C52D02', 'EA5B62A69DE3FFB1D78033143E67EC545149081C', 'EA7E078A544EB0EF3CE0912FEA6350BD72B9248C', 'EAB7557DE2C637133DE7FD9F59DF95B9B032FDFC', 'EB877F6C8D0310034D417C8E19856045DB312256', 'EBC6DA5A9FCFD298FD89B53DF8D3D479C77CA8A1', 'ED6733F7153177BEC3C53FC0B407F166ABAA4771', 'ED81B3D57430CD69F63A870DF80DAE082F00F2B6', 'EDA2F36F10E2351F6139CC1F7A1FAD7CE9BD7B88', 'EE2ACD8B04EDEB34DCA8F8729016AD4BAFEEF8B7', 'EEDD68FC212BB4852D306CB1507FD8AF9CA06870', 'EF978FF5850CA7680283244BBE5512E36BBBF88C', 'F1C71A67DBD7BF6E059564D42054CF0221CA1710', 'F5CB0C0F66E9AA727FD5741E82E1BECD21782E9E', 'F8C609BDD350C0D808599DE060F0C642D041B120', 'FA6605EDA10E7F1EFBA3FEA1F0F7CC226CC705A5', 'FADA02AE379131540D07A408B1ECA90C3C16C4D2', 'FADED0BBC56DA27A818D38D38947E4370BF7985C', 'FB926E835660040267689B27E176A0C5AC80AEF2', 'FF75924F15B8AADEF786B73F8DC05C5AD6223F7D', 'b180c44f-09f5-4d58-b942-6813f4b39297', 'd84aedfa-3037-43d8-b79b-bb1cc8d4bd9c', 'FDB7669045616ADB335F09EE45BCAAA5BD071A33', 'DF55D0F1B7D70B2007B4B9AB7CE751EC07555453', 'E0E1DF16874C60B2C232F94EBC8C0674D663FFE3', 'DF03F0C3EDB6CA037E09BDECB50430601FAE9275', 'DF3B9426ADBB698CB6BC513DEDF961B24FF96133', 'DF44F9023C5E9494F56F0DA04D4C0695975EA4D1', 'DEF9D70BC70DD6FDB97D15C24D172C976AED6E17', 'de1c2b90-46f9-49f3-8a16-5d39cdc04c3d', 'e61f8443-4c1f-430b-bf80-7b4350ac1957', 'f6a9894e-83a8-4404-8e1a-f4db66a82681', 'FE65FCFE5B2D6C431B7079FFE98A006F94E7E72E', 'E71F725330C12D573ECF9102452A33422581EE99', 'DF86F79CD685C1D22C87A4C7403F2D693EF53EBE', 'EB56CE583D16CF380246658016A17A1075CCCD01']
    # if only last file is missing: set timestamp to current time for previously available bikes at "callabike-15.json" stations
    # if more than one file is missing: set timestamp to current time for all previously available bikes
    if(missingFiles == "lastFile"):
        for bike in callabike_bike_status_dict.values():
            # if bike was at one of the callabike-15 stations at the previous minute
            if(bike[1] in callabike15_stations_list and bike[2] == datetime_last_minute):
                # as the last status is potentially missing
                # manually set since-timestamp of bike to current time
                bike[2] = datetime_current
    elif(missingFiles == "moreFiles"):
        # loop through all bikes
        for bike in callabike_bike_status_dict.values():
            # if bike was available at the previous minute
            if(bike[2] == datetime_last_minute):
                # manually set since-timestamp of bike to current time
                bike[2] = datetime_current
    # print(timestamp + ': ' + "Not all files")

# %%
# get execution time:
# import time
# start_time = time.time()

start_day = start_datetime.day
start_month = start_datetime.month

callabike_bike_rides_list = []
callabike_exception_dict = dict()

start_hour = start_datetime.hour
end_hour = end_datetime.hour

# for all minutes within date
# for day in range(start_day, start_day+1):
for day in range(5, 6):
    # for hour in range(start_hour,end_hour):
    date = '2021-' + f'{start_month:02d}' + '-' + f'{day:02d}'
    for hour in range(0,24):
        for minute in range(0,60):
            # format date and time strings (YYYY-MM-DD and HH-MM), append to directory path
            time_hhmm = f'{hour:02d}' + '-' + f'{minute:02d}'
            DIR = 'json/' + date + '/' + time_hhmm;
            # timestamp of batch of files currently being processed
            datetime_current = datetime.datetime.strptime(date + '-' +  time_hhmm, '%Y-%m-%d-%H-%M')
            # timestamp of previous minute
            datetime_last_minute = datetime_current - datetime.timedelta(minutes=1)
            # if given directory exists
            if(os.path.exists(DIR)):
                # CALL-A-BIKE
                # go through numbers 0-18
                # for callabike_json_number in range(0,1):
                for callabike_json_number in range(0,19):
                    # if call-a-bike JSON with given number exists
                    json_path = DIR+'/callabike-'+str(callabike_json_number)+'.json'
                    if(os.path.exists(json_path)):
                        try:
                            # open JSON and write subarray 'items' to array bikes
                            with open(json_path) as bike_json:
                                jsonObject = json.load(bike_json)
                                bike_json.close()
                            bikes = jsonObject['items']

                            # if it is the first file (callabike_0.json)
                            # href_sample_bike is updated every minute this way (in case it changes)
                            if(callabike_json_number == 0):
                                # take rentalObject href of first bike
                                href_sample_bike = str(bikes[0]['rentalObject'])
                                # find out beginning and end position of bike ID within that href
                                left_cut_bike = href_sample_bike.rfind("rentalobjects/")+14
                                right_cut_bike = href_sample_bike.rfind("'}'")-1

                                # take area href of first bike
                                href_sample_station = str(bikes[0]['area'])
                                # find out beginning and end position of station ID within that href
                                left_cut_station = href_sample_station.rfind("areas/")+6
                                right_cut_station = href_sample_station.rfind("'}'")-1

                                # get number of bikes available for this minute
                                bike_number = jsonObject['size']

                            for bike in bikes:
                                bike_href = str(bike['rentalObject'])
                                # cut bike ID out of rentalobject href
                                bike_id = bike_href[:right_cut_bike][left_cut_bike:]

                                station_href = str(bike['area'])
                                # if area is 65D863257FDF847B1F2807E7E346B83F8C752E3F (Stadtgebiet Berlin), indicating a free-floating bike
                                # comparing whole href does NOT work, as the URL changes over time!
                                # if(station_href == "{'href': 'https://api.deutschebahn.com:80/apiv4/v1/areas/65D863257FDF847B1F2807E7E346B83F8C752E3F'}"):
                                if('65D863257FDF847B1F2807E7E346B83F8C752E3F' in station_href):
                                    station_id = ''
                                else:
                                    # if bike is at an actual station: cut station ID out of area href
                                    station_id = station_href[:right_cut_station][left_cut_station:]
                                coordinates = str(bike['position']['coordinates'])

                                # if bike doesn't exist in database yet
                                if(bike_id not in callabike_bike_status_dict.keys()):
                                    # add to set of new bikes
                                    callabike_new_bikes_list.append(list([bike_id]))
                                # else (= exists) if "since" timestamp of current status is NOT equal to the previous minute 
                                # => bike was not previously available and therefore gone
                                # AND not equal to current minute -> work-around for Call-A-Bike exception with multiple entries of same bike within same minute
                                elif(callabike_bike_status_dict[bike_id][2] != datetime_last_minute and callabike_bike_status_dict[bike_id][2] != datetime_current):
                                    start_coordinates = callabike_bike_status_dict[bike_id][0]
                                    start_station = callabike_bike_status_dict[bike_id][1]
                                    # bike gone since: one minute after the last time it was available
                                    since = callabike_bike_status_dict[bike_id][2] + datetime.timedelta(minutes=1)

                                    # bike ride tuple: bike ID, start coordinates, start station, end coordinates, end station, since, until
                                    callabike_bike_rides_list.append((bike_id, start_coordinates, coordinates, start_station, station_id, since, datetime_current))
                                # update new available status in dictionary (or create new status if not yet existent)
                                callabike_bike_status_dict[bike_id] = [coordinates, station_id, datetime_current]
                    
                        # catch JSON errors and print them with file path
                        except JSONDecodeError as e:
                            handleAPIException("JSONDecodeError")
                        except ValueError as e:
                            handleAPIException("ValueError")
                        except KeyError as e:
                            handleAPIException("KeyError")
                        except TypeError as e:
                            handleAPIException("TypeError")
                        except Error as e:
                            handleAPIException("Error")
                    # if callabike-0 does not exist in directory -> API exception!
                    elif callabike_json_number == 0:
                        handleAPIException("NoFile")
                        # break the loop of all files of the minute
                        break
                    # if the last file should exist given the number of bikes
                    # e.g. callabike-15 is missing even though number of bikes > 1500
                    # -> check if missing json number is 15 (> 1500 rounded down)
                    elif callabike_json_number == math.floor(bike_number/100):
                        handleNotAllFilesException("lastFile")
                        break
                    # if more than just the last file is missing
                    elif callabike_json_number < math.floor(bike_number/100):
                        handleNotAllFilesException("moreFiles")
                        break

getAndInsertNewStations()
print('Inserting new stations done!')

pp.pprint(callabike_new_bikes_list)
cursor.executemany("INSERT INTO bike (bike_id, provider) VALUES (%s, 'callabike') ON DUPLICATE KEY UPDATE bike_id=bike_id", callabike_new_bikes_list)
connection.commit()
print('Inserting bikes done!')

# at the end of the day (or of the period)
insertLastBikeStatus(callabike_bike_status_dict, datetime_current)
print('Inserting last bike status done!')

callabike_actual_bike_rides_list = [ride for ride in callabike_bike_rides_list if not ride[1]=='no_ride']
insertBikeRides(callabike_actual_bike_rides_list)
print('Inserting bike rides done!')

insertExceptions(callabike_exception_dict)
print('Inserting exceptions done!')

# get execution time:
# print("--- %s seconds ---" % (time.time() - start_time))

pp.pprint(callabike_bike_rides_list)
# Out:
# new stations:
# []
# Inserting new stations done!
# []
# Inserting bikes done!
# Inserting last bike status done!
# Inserting bike rides done!
# [   ('NoFile', '2021-06-05 11:10'),
#     ('NoFile', '2021-06-05 22:21'),
#     ('NoFile', '2021-06-05 22:22'),
#     ('NoFile', '2021-06-05 22:23'),
#     ('NoFile', '2021-06-05 22:24'),
#     ('NoFile', '2021-06-05 22:25'),
#     ('NoFile', '2021-06-05 22:26'),
#     ('NoFile', '2021-06-05 22:27'),
#     ('NoFile', '2021-06-05 22:28'),
#     ('NoFile', '2021-06-05 22:29'),
#     ('NoFile', '2021-06-05 22:30'),
#     ('NoFile', '2021-06-05 22:31'),
#     ('JSONDecodeError', '2021-06-05 22:32'),
#     ('NoFile', '2021-06-05 22:34')]
# Inserting exceptions done!
# [   (   'ae16dee8-c383-4b9e-9b69-1ed2ffe6bbab',
#         'no_ride',
#         '[13.4220046, 52.520089]',
#         '',
#         '02A01A40044200D9D2CD2AEB0C9E579F01AE8E6B',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '72E4A8D196BB42481DECDCF8E294CD0558908FFE',
#         'no_ride',
#         '[13.472832, 52.50882]',
#         '',
#         '02E53D414E6DB10A3632433D657E3E90D23B3C24',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '884B839D74E3ABAC3B65BA36F24161640A478A79',
#         'no_ride',
#         '[13.4732536, 52.5092719]',
#         '',
#         '02E53D414E6DB10A3632433D657E3E90D23B3C24',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'E2C84783ED8BAE128C1D1EA04BCE3F7BA6067671',
#         'no_ride',
#         '[13.4732536, 52.5092719]',
#         '',
#         '02E53D414E6DB10A3632433D657E3E90D23B3C24',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C814987937BAA1C65E2C41D356D0898ABD423C74',
#         'no_ride',
#         '[13.316606, 52.51076]',
#         '',
#         '04B697D7AB5ED27FC69D14D76E5F43ACC5F95599',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9C1FDA3C36EFE30425F64D990B51460C1C0605E7',
#         'no_ride',
#         '[13.316486, 52.51065]',
#         '',
#         '04B697D7AB5ED27FC69D14D76E5F43ACC5F95599',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '453F7EA7EA5E419E0EE52FF1A969926C6D677936',
#         'no_ride',
#         '[13.316426, 52.51065]',
#         '',
#         '04B697D7AB5ED27FC69D14D76E5F43ACC5F95599',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'D52305CA98052D9A69EF25A8ED10457CE9AF0332',
#         'no_ride',
#         '[13.316401, 52.51072]',
#         '',
#         '04B697D7AB5ED27FC69D14D76E5F43ACC5F95599',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C821E050DA7002B00464D3AA476C37FEEA91E395',
#         'no_ride',
#         '[13.3164462, 52.5107085]',
#         '',
#         '04B697D7AB5ED27FC69D14D76E5F43ACC5F95599',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'E76269DB9434BCB78A820C3666094E12DD0F3408',
#         'no_ride',
#         '[13.367013, 52.496845]',
#         '',
#         '05A7A06BC2E98193F3DB5B0F6C9436FE0084D1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CFA64B3D89D15E048B713215D9C87F5594B0022B',
#         'no_ride',
#         '[13.366865, 52.496853]',
#         '',
#         '05A7A06BC2E98193F3DB5B0F6C9436FE0084D1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'AE3426D5099324B75832E7B3722FA0B761FEA9EC',
#         'no_ride',
#         '[13.367059, 52.49679]',
#         '',
#         '05A7A06BC2E98193F3DB5B0F6C9436FE0084D1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '1D32275E3041705136FA4772F34070A1AF4EFF05',
#         'no_ride',
#         '[13.367016, 52.496944]',
#         '',
#         '05A7A06BC2E98193F3DB5B0F6C9436FE0084D1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'B6224E48EEE97B2D34546553864BAB80B5535ABD',
#         'no_ride',
#         '[13.439726, 52.512794]',
#         '',
#         '070F0B5EA9656CCA0B7255DEB0D633A04962B294',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '5D97D3A105E3C4E538DFE3C73D1AF5976D01CE75',
#         'no_ride',
#         '[13.4397367, 52.513433]',
#         '',
#         '070F0B5EA9656CCA0B7255DEB0D633A04962B294',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'E066B0DB4FF32604BCCD1D4B89C84F28CB6E968A',
#         'no_ride',
#         '[13.4397367, 52.513433]',
#         '',
#         '070F0B5EA9656CCA0B7255DEB0D633A04962B294',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '6A7586259B80989B2B3DC2DC6CA9E6F7BC3C6E99',
#         'no_ride',
#         '[13.4397367, 52.513433]',
#         '',
#         '070F0B5EA9656CCA0B7255DEB0D633A04962B294',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '2F2A654612AE879C948B41A3FC2231F183DF346B',
#         'no_ride',
#         '[13.463289, 52.499496]',
#         '',
#         '0821283BC81F638D357A4815702568410703235F',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F02BE56F19E4FD8331110651F9917C1F2D630AC7',
#         'no_ride',
#         '[13.284294, 52.51877]',
#         '',
#         '0853f7a6-efb9-47ea-bea1-6acf7d126f7a',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '091107F06F11258D90B6E19F3D714FE727F590E0',
#         'no_ride',
#         '[13.427963, 52.507294]',
#         '',
#         '0902493F1154C63633BFF38A475E922E00FE0857',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '3C68F6FFB03C0BE1D68F8109E54890C97D652D8E',
#         'no_ride',
#         '[13.428018, 52.507603]',
#         '',
#         '0902493F1154C63633BFF38A475E922E00FE0857',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'd6a45235-fd66-409c-99ec-89094abf124e',
#         'no_ride',
#         '[13.3859415, 52.471912]',
#         '',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '70F4229740E3038AC0A28505815203E61C83A3BF',
#         'no_ride',
#         '[13.385305, 52.47212]',
#         '',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '69C92702E8A0CEF6973E2197E064A33C41E7ED40',
#         'no_ride',
#         '[13.385959, 52.471962]',
#         '',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'd9079be9-4ad4-4ae2-b0bb-c70a7cd9ff41',
#         'no_ride',
#         '[13.385473, 52.472115]',
#         '',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '79F77C26B54052576485F69D48778249C4942208',
#         'no_ride',
#         '[13.385513, 52.472088]',
#         '',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '03CEB9BDA4B717A0FC0A20F563E733C8460DFEF6',
#         'no_ride',
#         '[13.359388, 52.53348]',
#         '',
#         '0DEE75199BA081F4ED28362215B566C70C9FBE16',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '86439DAF43D84D9E962DFF7B685C260EF0CFD34A',
#         'no_ride',
#         '[13.359308, 52.53361]',
#         '',
#         '0DEE75199BA081F4ED28362215B566C70C9FBE16',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '6c619daa-7d1f-46b7-a5ff-f3ecaf9ed49c',
#         'no_ride',
#         '[13.363751, 52.476196]',
#         '',
#         '1031D91818C336FE48E6B6D8B73B4BB42F5513A6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CDF832E3BFEF038AFAD041F2B0DB114FB240E90E',
#         'no_ride',
#         '[13.364404, 52.475723]',
#         '',
#         '1031D91818C336FE48E6B6D8B73B4BB42F5513A6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F97618E3229E653159933DF006DB4A25C89CE954',
#         'no_ride',
#         '[13.36413, 52.47575]',
#         '',
#         '1031D91818C336FE48E6B6D8B73B4BB42F5513A6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '3E124458435564BD11044B390FD70E481D1F748F',
#         'no_ride',
#         '[13.363625, 52.475803]',
#         '',
#         '1031D91818C336FE48E6B6D8B73B4BB42F5513A6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '83323AE67CF3C6036EFC668303B85576BD84D78C',
#         'no_ride',
#         '[13.364297, 52.475548]',
#         '',
#         '1031D91818C336FE48E6B6D8B73B4BB42F5513A6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'c1289593-54b9-4f59-a656-24d590977202',
#         'no_ride',
#         '[13.3640742, 52.4757526]',
#         '',
#         '1031D91818C336FE48E6B6D8B73B4BB42F5513A6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9E9C69BC24CAABD28C6B5005BDA7170B2A2F51A0',
#         'no_ride',
#         '[13.3640742, 52.4757526]',
#         '',
#         '1031D91818C336FE48E6B6D8B73B4BB42F5513A6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8C24818699F221428E579A6E975A820D27B08A33',
#         'no_ride',
#         '[13.386307, 52.516533]',
#         '',
#         '1244912B84D1392FD997BD6E2BC8EC6BD71A63B3',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '38EA4D9CC96749949CB3DBA58DF833390376D827',
#         'no_ride',
#         '[13.386348, 52.516514]',
#         '',
#         '1244912B84D1392FD997BD6E2BC8EC6BD71A63B3',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C3132C315074F076D40A3794E5C0379A4DB5981F',
#         'no_ride',
#         '[13.4422865, 52.50123]',
#         '',
#         '12BDBDC8CB6AFAB60CB472423659A73048FFC159',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '584C9F1C5CF138A0D16AC5DC3BDBC449AEDA86AC',
#         'no_ride',
#         '[13.442456, 52.50123]',
#         '',
#         '12BDBDC8CB6AFAB60CB472423659A73048FFC159',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '2496EBEA9F9D799A71B9F9AE6E5D7CB245F59D20',
#         'no_ride',
#         '[13.442256, 52.501137]',
#         '',
#         '12BDBDC8CB6AFAB60CB472423659A73048FFC159',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '50B2A4E8481E88127DAC113139A7D7482B09D0F8',
#         'no_ride',
#         '[13.4419985, 52.50118]',
#         '',
#         '12BDBDC8CB6AFAB60CB472423659A73048FFC159',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '71CA10EEEF3D1C0B5CCC82D9E910344582EC31D5',
#         'no_ride',
#         '[13.4420728, 52.5011724]',
#         '',
#         '12BDBDC8CB6AFAB60CB472423659A73048FFC159',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F175A412E911A49CB6556058FB114B994D13FB06',
#         'no_ride',
#         '[13.490457, 52.514763]',
#         '',
#         '1468BD1C6285AA67D9007CABC19E9E30B5A250D6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '18b7f0eb-6a52-4624-a2e4-a2b5b8cf8b79',
#         'no_ride',
#         '[13.49048, 52.51479]',
#         '',
#         '1468BD1C6285AA67D9007CABC19E9E30B5A250D6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CC5EF40C5B0EC6C16EEE91DEBB9DA7A37E67692E',
#         'no_ride',
#         '[13.490425, 52.51486]',
#         '',
#         '1468BD1C6285AA67D9007CABC19E9E30B5A250D6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CDCED46912A021B6F03A788EE6495276C86863B1',
#         'no_ride',
#         '[13.490424, 52.51457]',
#         '',
#         '1468BD1C6285AA67D9007CABC19E9E30B5A250D6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '615EDC74EFE9720EEB42563DEA3E3D0D614C0245',
#         'no_ride',
#         '[13.4279162, 52.4902087]',
#         '',
#         '151928A6962C842E094B8577F5781C935965F73F',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '1E57285AD6D2CF701A034E798AC0AB63E466047B',
#         'no_ride',
#         '[13.3978567, 52.5277722]',
#         '',
#         '16ED7419CFD91D57DE313468B9CC492DE7ED243A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'd3e3eb3f-8bfb-4692-af6d-2281dc678ea6',
#         'no_ride',
#         '[13.3978567, 52.5277722]',
#         '',
#         '16ED7419CFD91D57DE313468B9CC492DE7ED243A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '19312C980D550C6789849855388D2BAB0AFFEB92',
#         'no_ride',
#         '[13.3978567, 52.5277722]',
#         '',
#         '16ED7419CFD91D57DE313468B9CC492DE7ED243A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '853DC47541B74A3B098AABE60CC190DCCEDFBCE5',
#         'no_ride',
#         '[13.3978567, 52.5277722]',
#         '',
#         '16ED7419CFD91D57DE313468B9CC492DE7ED243A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'd6d1ec92-a042-40bb-a1ec-cfc8ae73b30a',
#         'no_ride',
#         '[13.3978567, 52.5277722]',
#         '',
#         '16ED7419CFD91D57DE313468B9CC492DE7ED243A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'FEC74560355F7808552BE3A21E6171FF9B9B9298',
#         'no_ride',
#         '[13.3978567, 52.5277722]',
#         '',
#         '16ED7419CFD91D57DE313468B9CC492DE7ED243A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'a6f4fefb-68f4-4c72-8b7e-b6b53a85620e',
#         'no_ride',
#         '[13.3978567, 52.5277722]',
#         '',
#         '16ED7419CFD91D57DE313468B9CC492DE7ED243A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '37C34A2800FC9EDF1EC73A0CFFBC00848C529E4E',
#         'no_ride',
#         '[13.43552, 52.53279]',
#         '',
#         '18F1A06DC029BB4E56E2E0E68FB6234BEBE22C04',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CA8416E969E6541F3ACC9EFBF93AC9C09AD4F349',
#         'no_ride',
#         '[13.43552, 52.53279]',
#         '',
#         '18F1A06DC029BB4E56E2E0E68FB6234BEBE22C04',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'E05F2323C9FC19CAA32028A9D9D81FD634A8C63A',
#         'no_ride',
#         '[13.414743, 52.520527]',
#         '',
#         '199C8809901D08AD7410C4284F95C0D17FE2A0C4',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '3778458ACA4F4074707C41CC56D7E11DD3B021E0',
#         'no_ride',
#         '[13.414716, 52.520546]',
#         '',
#         '199C8809901D08AD7410C4284F95C0D17FE2A0C4',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'FBCE6120174C4597253CA60FC2FE50E4C8E1BCFC',
#         'no_ride',
#         '[13.414731, 52.52052]',
#         '',
#         '199C8809901D08AD7410C4284F95C0D17FE2A0C4',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '59A59D2DE85ED5DAD2A01DE9079597FA7600D922',
#         'no_ride',
#         '[13.414723, 52.520554]',
#         '',
#         '199C8809901D08AD7410C4284F95C0D17FE2A0C4',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F8BEAB353D95558F130BCEC498AA426D89D58016',
#         'no_ride',
#         '[13.4149342, 52.5205819]',
#         '',
#         '199C8809901D08AD7410C4284F95C0D17FE2A0C4',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'B98624BDF92D225CF7AC7909110EA836F32E1D16',
#         'no_ride',
#         '[13.4149342, 52.5205819]',
#         '',
#         '199C8809901D08AD7410C4284F95C0D17FE2A0C4',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '09090EC8143098D7CC5CABCF120995A43008F026',
#         'no_ride',
#         '[13.394251, 52.532352]',
#         '',
#         '1A4A15EAFABA6A9BD939C26442BB757F477BC3C6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '889D1803E6D4396011505659C4D52FCB192D959E',
#         'no_ride',
#         '[13.394227, 52.532368]',
#         '',
#         '1A4A15EAFABA6A9BD939C26442BB757F477BC3C6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9c3cf270-1974-4246-a7a9-87b860bbd55a',
#         'no_ride',
#         '[13.394228, 52.532307]',
#         '',
#         '1A4A15EAFABA6A9BD939C26442BB757F477BC3C6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '282457645A7381D70F8CC8555FC2764F3CB46C0C',
#         'no_ride',
#         '[13.3943939, 52.5323149]',
#         '',
#         '1A4A15EAFABA6A9BD939C26442BB757F477BC3C6',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'BA3D503B5337FFC2022A6DA142502EBB4563687E',
#         'no_ride',
#         '[13.4181, 52.515003]',
#         '',
#         '1A57973F2CBB28ADF1BC417B9669CA9E51179C48',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '64A07795513151B214A8DF621197E9930879BC63',
#         'no_ride',
#         '[13.418741, 52.515198]',
#         '',
#         '1A57973F2CBB28ADF1BC417B9669CA9E51179C48',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'D1947A456552B0344DDDC159613C8F16547D5834',
#         'no_ride',
#         '[13.41763, 52.51524]',
#         '',
#         '1A57973F2CBB28ADF1BC417B9669CA9E51179C48',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'FC3AE29F7B61431E24D42610075C092FBECD5E50',
#         'no_ride',
#         '[13.40556, 52.53265]',
#         '',
#         '1B000E6265C81E27CF8A7112964867F4559CE8DB',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '6CFBABAAFC280D86C0E7619BCE5FD791CFDB3B31',
#         'no_ride',
#         '[13.3541125, 52.4969744]',
#         '',
#         '1C3F1DC06DC06F7EA17545AD5CE351A94721283A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CDAFD3E9CE6ADB3FB4CB5370275493DBC5819FE3',
#         'no_ride',
#         '[13.3541125, 52.4969744]',
#         '',
#         '1C3F1DC06DC06F7EA17545AD5CE351A94721283A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '50FD1637E690CCC4A47F301B81CD50210A98635E',
#         'no_ride',
#         '[13.3541125, 52.4969744]',
#         '',
#         '1C3F1DC06DC06F7EA17545AD5CE351A94721283A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'BABADD3BAFB605A1AD620862E27B26D261DA1674',
#         'no_ride',
#         '[13.328757, 52.500225]',
#         '',
#         '1CD8F63BFDF35D22A5EDB65C1F8CDA0F3D5B122F',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9502001EBC100A7C3CDB3444B51CAACD80C657E6',
#         'no_ride',
#         '[13.329367, 52.500187]',
#         '',
#         '1CD8F63BFDF35D22A5EDB65C1F8CDA0F3D5B122F',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'BA4EA8C897B1B103D79753C92E2725AF84626E7C',
#         'no_ride',
#         '[13.417946, 52.49941]',
#         '',
#         '1E1554E253D2E5960E2E290059589A7877012449',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'E3431FE077E99DAE3FD5D3586BAD6039D6ADD385',
#         'no_ride',
#         '[13.417823, 52.499355]',
#         '',
#         '1E1554E253D2E5960E2E290059589A7877012449',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '7FBD00EE091A3D5C61CAE5D6692FFB9CE80AC4F2',
#         'no_ride',
#         '[13.417911, 52.499397]',
#         '',
#         '1E1554E253D2E5960E2E290059589A7877012449',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'FC247C94EEE1784CCEE2672EDA230EB0538A1E13',
#         'no_ride',
#         '[13.4175816, 52.4992507]',
#         '',
#         '1E1554E253D2E5960E2E290059589A7877012449',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '848B240B28C3501672366AD3DC3198DF7E4A4D36',
#         'no_ride',
#         '[13.396738, 52.51335]',
#         '',
#         '1E71093C3C3F45C6E3608B8F60CA74F93FD23849',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C86B7EF4AC2D76537CAC44B57460B0F854D0ACF7',
#         'no_ride',
#         '[13.396707, 52.513268]',
#         '',
#         '1E71093C3C3F45C6E3608B8F60CA74F93FD23849',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'e3e23dfd-89ee-46f2-9874-6d9ae8a374e2',
#         'no_ride',
#         '[13.396641, 52.513275]',
#         '',
#         '1E71093C3C3F45C6E3608B8F60CA74F93FD23849',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '1260fee1-bf31-4a01-8d02-2c50469746f9',
#         'no_ride',
#         '[13.327083, 52.508774]',
#         '',
#         '1ECB4309B901F7CABF8FF6518178DD60DBB97773',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C6BF7616D967E913B049DA9DF0C71B24D31F6FF9',
#         'no_ride',
#         '[13.327289, 52.50888]',
#         '',
#         '1ECB4309B901F7CABF8FF6518178DD60DBB97773',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'f84e310f-5705-416f-aa89-d0de1bd18272',
#         'no_ride',
#         '[13.327165, 52.508793]',
#         '',
#         '1ECB4309B901F7CABF8FF6518178DD60DBB97773',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'DB67CBDF844E623039A5E60F3E96700DABFF2BB4',
#         'no_ride',
#         '[13.4066463, 52.4986318]',
#         '',
#         '1F049CBFFC35D9ACF23F3C478F41F9245921F70C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '46A3363C234735388954874EEE22B6C973A3857C',
#         'no_ride',
#         '[13.4066463, 52.4986318]',
#         '',
#         '1F049CBFFC35D9ACF23F3C478F41F9245921F70C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8dffe632-59a0-458c-a0a9-9e5c3d291ce0',
#         'no_ride',
#         '[13.4066463, 52.4986318]',
#         '',
#         '1F049CBFFC35D9ACF23F3C478F41F9245921F70C',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F1CFD423E83243FA94DBC3732324B8D839042C21',
#         'no_ride',
#         '[13.328253, 52.515503]',
#         '',
#         '1F97E4C3B81AB9F5BB90762C6B7FF4AB3B4B8A79',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9D10BFC4F23B76C687EDDF4B740F56A9099F9EBE',
#         'no_ride',
#         '[13.328268, 52.515488]',
#         '',
#         '1F97E4C3B81AB9F5BB90762C6B7FF4AB3B4B8A79',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'BB8D381394C4D4ADAD54B3B4B50A8CCC8BEE6605',
#         'no_ride',
#         '[13.32827, 52.515553]',
#         '',
#         '1F97E4C3B81AB9F5BB90762C6B7FF4AB3B4B8A79',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9BC0856D25E1302E930BEC3647D322C4FA9F878B',
#         'no_ride',
#         '[13.349369, 52.524166]',
#         '',
#         '20AB0E31469EA7E33B111C88F0F3F21BFA347A59',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8490D74B42C4107380B2F74C084AE0396820C266',
#         'no_ride',
#         '[13.349174, 52.52417]',
#         '',
#         '20AB0E31469EA7E33B111C88F0F3F21BFA347A59',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '3D7AC8A7D365D1DD5F9844AE7471504AB916937C',
#         'no_ride',
#         '[13.34955, 52.52429]',
#         '',
#         '20AB0E31469EA7E33B111C88F0F3F21BFA347A59',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '24787F5376883AE1301223CE78FE6C12BD8CCB00',
#         'no_ride',
#         '[13.34955, 52.52429]',
#         '',
#         '20AB0E31469EA7E33B111C88F0F3F21BFA347A59',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '3562C445D0E104E019DA8ED927549DA022F51CF1',
#         'no_ride',
#         '[13.34955, 52.52429]',
#         '',
#         '20AB0E31469EA7E33B111C88F0F3F21BFA347A59',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'DC18B064FB0B0B738E48101C40EFAFCBBAFF444F',
#         'no_ride',
#         '[13.483329, 52.50334]',
#         '',
#         '21B817DFDDA2EAEF57E361DDE185C24268AE3BEE',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '111F99687F21C90383AB3632091F679218274433',
#         'no_ride',
#         '[13.483346, 52.503338]',
#         '',
#         '21B817DFDDA2EAEF57E361DDE185C24268AE3BEE',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '35AE749E515A30BF9BCD471F718FAF2369722B5C',
#         'no_ride',
#         '[13.427863, 52.496307]',
#         '',
#         '223EF81B339DEEE3FE85F3CD819EF4670C72FAE8',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C3719951088016991A4824818BB4D0BB6FA95F11',
#         'no_ride',
#         '[13.4275433, 52.4964305]',
#         '',
#         '223EF81B339DEEE3FE85F3CD819EF4670C72FAE8',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '97C07C48FFF095E7E7D896F75D66A1A55C27E469',
#         'no_ride',
#         '[13.427195, 52.495914]',
#         '',
#         '223EF81B339DEEE3FE85F3CD819EF4670C72FAE8',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '74B9E0CE86CCA1307A7EA3CD9812A8A083E07C4A',
#         'no_ride',
#         '[13.432466, 52.491432]',
#         '',
#         '2331213FD4C7C9918F83E4324F7DB2B526DAD1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '14140bab-583f-4d57-a45c-b7dfd63ed9ec',
#         'no_ride',
#         '[13.432843, 52.49198]',
#         '',
#         '2331213FD4C7C9918F83E4324F7DB2B526DAD1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '36CE1A48EA902E1F37D21E070380B3AFAD9ED5D4',
#         'no_ride',
#         '[13.432562, 52.491486]',
#         '',
#         '2331213FD4C7C9918F83E4324F7DB2B526DAD1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '3719528EB58CE5C4D1B6D192940755007E32DAC0',
#         'no_ride',
#         '[13.43249, 52.49148]',
#         '',
#         '2331213FD4C7C9918F83E4324F7DB2B526DAD1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '451E8B2D9A46A93F674B6CED3701C78988647977',
#         'no_ride',
#         '[13.43249, 52.49148]',
#         '',
#         '2331213FD4C7C9918F83E4324F7DB2B526DAD1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '94C4BA82030000170C50510425D97C74BCF800EF',
#         'no_ride',
#         '[13.43249, 52.49148]',
#         '',
#         '2331213FD4C7C9918F83E4324F7DB2B526DAD1DA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '45D63086EF34A45128A82D89DEBAB4874E5D6CA6',
#         'no_ride',
#         '[13.4605641, 52.4941705]',
#         '',
#         '23B1227FA9D82F04E1030A1F79CBA42390E099E5',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '53A61C3F6837C9A65163FFECFCA235EE8D62A3DA',
#         'no_ride',
#         '[13.4605641, 52.4941705]',
#         '',
#         '23B1227FA9D82F04E1030A1F79CBA42390E099E5',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'BA152E9F96751E46D45BA58428C9A5E09C80831B',
#         'no_ride',
#         '[13.340045, 52.528465]',
#         '',
#         '2513CF44BADFEE2F80C9FF4569762C8FF9339F76',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '3F81F82DD275A42D55773F144CC4EFA156CB62B7',
#         'no_ride',
#         '[13.338908, 52.528526]',
#         '',
#         '2513CF44BADFEE2F80C9FF4569762C8FF9339F76',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8c779b18-98f9-446e-a2fb-e67f963f3cb5',
#         'no_ride',
#         '[13.3389365, 52.5283564]',
#         '',
#         '2513CF44BADFEE2F80C9FF4569762C8FF9339F76',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '5DFE55837B9A8A1EBA2DF3887AFFA42A0B993B02',
#         'no_ride',
#         '[13.3389365, 52.5283564]',
#         '',
#         '2513CF44BADFEE2F80C9FF4569762C8FF9339F76',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '61d482da-bd7f-4b93-bd92-42570ba953b4',
#         'no_ride',
#         '[13.3389365, 52.5283564]',
#         '',
#         '2513CF44BADFEE2F80C9FF4569762C8FF9339F76',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'DC16691C01E648ADF25CBB9AC497E8218A565E75',
#         'no_ride',
#         '[13.413863, 52.490704]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '1FD73BA5B3B0F691BA3A46ED483850C3DFBA45A0',
#         'no_ride',
#         '[13.413507, 52.49149]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '0B985213E1FDF94C15B2E9C4A114FB7D61E32196',
#         'no_ride',
#         '[13.41306, 52.491158]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '2583ce66-0c1a-4026-920e-46d90e47602f',
#         'no_ride',
#         '[13.413496, 52.49169]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '63E8D09D324AE0BAD383F36C66C9EE18A86FA0AE',
#         'no_ride',
#         '[13.41352, 52.49156]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '2FAF06B8FE1520B5295F226F49B0A9C79E4DE93B',
#         'no_ride',
#         '[13.41352, 52.49156]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '26AB16716D2F03D71D6B090E83940C54E078B81E',
#         'no_ride',
#         '[13.41352, 52.49156]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F4487BFC09595C1430B436A574EBC2C7F1B219FA',
#         'no_ride',
#         '[13.41352, 52.49156]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '66008967067505D7A667E99C45A541E49496E9F0',
#         'no_ride',
#         '[13.41352, 52.49156]',
#         '',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'DD0948D550BDB9DC7796F426A06BFABCB9EC98C5',
#         'no_ride',
#         '[13.308254, 52.50323]',
#         '',
#         '2650AC94DE315757FC3EA44B2D99618D92E04568',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '19BB683F441301C6F928B2C6D9B15F468531D017',
#         'no_ride',
#         '[13.308156, 52.503204]',
#         '',
#         '2650AC94DE315757FC3EA44B2D99618D92E04568',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '17B96D590BD1B01F66C12A908BA2114C8EE518E2',
#         'no_ride',
#         '[13.3080509, 52.5031154]',
#         '',
#         '2650AC94DE315757FC3EA44B2D99618D92E04568',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '6D33E53F9F78E077179C93EF668F911E6728CB9D',
#         'no_ride',
#         '[13.3080509, 52.5031154]',
#         '',
#         '2650AC94DE315757FC3EA44B2D99618D92E04568',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '6CD6F500C99D0A8CD4D9895F11DEFED4AB93E653',
#         'no_ride',
#         '[13.4005898, 52.5183737]',
#         '',
#         '2674278063DF98CD69D7DB038D11E72F59354EF4',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '28472AA2E5EFD2269F7C9F43170CA481B652247D',
#         'no_ride',
#         '[13.40826, 52.55108]',
#         '',
#         '26A462A6D34C35D25CABA0F593B1CD4A4329D564',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '2AB3E2D8BFD3B4FE4F829BF3E0CBA1F7DF283FB6',
#         'no_ride',
#         '[13.408223, 52.55106]',
#         '',
#         '26A462A6D34C35D25CABA0F593B1CD4A4329D564',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C00216606D0BB4385770E597C08247193E200D9D',
#         'no_ride',
#         '[13.333387, 52.50764]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '55AA02DEF4AC15D2BEE6EB5C277D928E38F4458A',
#         'no_ride',
#         '[13.33335, 52.507496]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'E8886845F31E5EB23F6E9778EEB62869082EAEEF',
#         'no_ride',
#         '[13.333379, 52.50755]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F52F5818B36E68113FB1BE09D06B7921E6C77F73',
#         'no_ride',
#         '[13.333325, 52.507492]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '09DED481DA214211293E0524C105FEF06F7F87BA',
#         'no_ride',
#         '[13.333351, 52.507496]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'ECC5D31F508A663E0EF3EE19172FC48A132BF25A',
#         'no_ride',
#         '[13.333344, 52.507473]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '4EAC355A2561B1D1AA9CD165D6930FEB8053B5F4',
#         'no_ride',
#         '[13.333437, 52.50749]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '52F4E1028F32D291BD72FAA296AD9D9A7F8ED58F',
#         'no_ride',
#         '[13.333345, 52.5074]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'ED96301BC19D63B49D67F6DD64F16FEF8031E58B',
#         'no_ride',
#         '[13.33342, 52.507504]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '4f728ab1-7af8-4b60-b22a-84757843b442',
#         'no_ride',
#         '[13.33332, 52.5074]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '14DE1F3DFD7123336325FB445E7C966ABB62C9CE',
#         'no_ride',
#         '[13.33332, 52.5074]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '5816B22F13EB92E9574E830116A7CC1E3699CCFA',
#         'no_ride',
#         '[13.33332, 52.5074]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F8B5BBA5BA4341529262227379C7B3CE3D717FDE',
#         'no_ride',
#         '[13.33332, 52.5074]',
#         '',
#         '273128FD89711871BCE50D08F053663AE702228A',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '0E05BA7A3A886DF51315F1051054F8F86DE83B59',
#         'no_ride',
#         '[13.326288, 52.51214]',
#         '',
#         '2926CD49BA12F2013A5C4C7E018FA455CE1841F5',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '03ee9849-a007-499a-9a5a-f9d134f63a62',
#         'no_ride',
#         '[13.32734, 52.51255]',
#         '',
#         '2926CD49BA12F2013A5C4C7E018FA455CE1841F5',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '40B7B4291187B30505CC75383114CD77C5AF4E6C',
#         'no_ride',
#         '[13.32682, 52.512486]',
#         '',
#         '2926CD49BA12F2013A5C4C7E018FA455CE1841F5',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '12BA9F32CE6B5D0B13B7ED6D5C96C7F27A6BCB92',
#         'no_ride',
#         '[13.327344, 52.512573]',
#         '',
#         '2926CD49BA12F2013A5C4C7E018FA455CE1841F5',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '57AAE166851A59F4E18243C02581F6C443C88C6B',
#         'no_ride',
#         '[13.3957, 52.48899]',
#         '',
#         '2994AD2BE1AE27F85F0B7CD869342A71A03193E1',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '542d6029-00f8-49d8-8278-6b1bd5af8fc0',
#         'no_ride',
#         '[13.3957, 52.48899]',
#         '',
#         '2994AD2BE1AE27F85F0B7CD869342A71A03193E1',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C00C820F79923E397BAFA287B089C7397ABFEC53',
#         'no_ride',
#         '[13.497768, 52.509747]',
#         '',
#         '2A02352CC1C639225D10DA11E377627766E26B39',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F8FD87411B41989FF9DC2B6601C46E84A4EB1490',
#         'no_ride',
#         '[13.49782, 52.5097]',
#         '',
#         '2A02352CC1C639225D10DA11E377627766E26B39',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'FE1EBC082141116A3783F22419525109B2FBB547',
#         'no_ride',
#         '[13.497791, 52.509727]',
#         '',
#         '2A02352CC1C639225D10DA11E377627766E26B39',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9188AD941CF2A38E4E357990C0B912D2D7D2966E',
#         'no_ride',
#         '[13.497783, 52.509747]',
#         '',
#         '2A02352CC1C639225D10DA11E377627766E26B39',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '43C748B86D035AF0E2ACC8B596A2DB95AC7A5249',
#         'no_ride',
#         '[13.3839119, 52.495023]',
#         '',
#         '2C0A964C367738F82B02D90AEFE900577CD9ECB1',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C772E232D9B3689816B0243FFEC7F8BDABA908B1',
#         'no_ride',
#         '[13.3839119, 52.495023]',
#         '',
#         '2C0A964C367738F82B02D90AEFE900577CD9ECB1',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '941EA1F336ADC2B7D1F5E2AFEC0BE37D9E981589',
#         'no_ride',
#         '[13.417976, 52.50663]',
#         '',
#         '2C7D1AEF6475150D682691DBDD045953447B4741',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'F52A1367EEE4FC250EAFED607C72447D2B9F5356',
#         'no_ride',
#         '[13.417998, 52.50665]',
#         '',
#         '2C7D1AEF6475150D682691DBDD045953447B4741',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CE86995A235B3C90AE3DADE66312FB88D922E630',
#         'no_ride',
#         '[13.41758, 52.50651]',
#         '',
#         '2C7D1AEF6475150D682691DBDD045953447B4741',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '4DF7A06CF9B4520E5F8B8DAC7BBB3D48BB4BEA6E',
#         'no_ride',
#         '[13.391017, 52.51979]',
#         '',
#         '2C9DE5AC1877B37A49A7DE2829B5690226165EBA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '0C261C94C6AB2CE35AD95C2F4643D6B0C774B04D',
#         'no_ride',
#         '[13.390936, 52.520298]',
#         '',
#         '2C9DE5AC1877B37A49A7DE2829B5690226165EBA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '08D42EAE1BECEDA193BFD4B04287B5E74FC29828',
#         'no_ride',
#         '[13.348884, 52.542145]',
#         '',
#         '2DB5F6F1C4C5E74D8D18B79B31E3208B57879364',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '2A97FF7A0EE8BA79CFCAFFBA23CA030EA73FAC8E',
#         'no_ride',
#         '[13.34904, 52.54222]',
#         '',
#         '2DB5F6F1C4C5E74D8D18B79B31E3208B57879364',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'A88F788D22380F08E9163FEA02B995AC8DAC2D32',
#         'no_ride',
#         '[13.34904, 52.54222]',
#         '',
#         '2DB5F6F1C4C5E74D8D18B79B31E3208B57879364',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'B86566AD284D36333C9201FF1A4B87A68ED27DF6',
#         'no_ride',
#         '[13.34904, 52.54222]',
#         '',
#         '2DB5F6F1C4C5E74D8D18B79B31E3208B57879364',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8B6695D0BD1C716F561A90A846A1E77D88E66157',
#         'no_ride',
#         '[13.34904, 52.54222]',
#         '',
#         '2DB5F6F1C4C5E74D8D18B79B31E3208B57879364',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'A9BAECEF83F04CB222D15015C11A55A5C4E0C6F7',
#         'no_ride',
#         '[13.431631, 52.4976178]',
#         '',
#         '2DF48437ACADDD33B1400DA502D418676BB01BCD',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8FE35150DBE1D19B4FB72E9D5D88C1BEED6675BA',
#         'no_ride',
#         '[13.431631, 52.4976178]',
#         '',
#         '2DF48437ACADDD33B1400DA502D418676BB01BCD',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'E20B04FE5DECD296B6E38575A43750FD7FDBDD65',
#         'no_ride',
#         '[13.431631, 52.4976178]',
#         '',
#         '2DF48437ACADDD33B1400DA502D418676BB01BCD',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8C9F015E2117933F321E42B6F2212AEEB7598A45',
#         'no_ride',
#         '[13.431631, 52.4976178]',
#         '',
#         '2DF48437ACADDD33B1400DA502D418676BB01BCD',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'DE86D107A103EAFE36E335ABBFF784410654A054',
#         'no_ride',
#         '[13.431631, 52.4976178]',
#         '',
#         '2DF48437ACADDD33B1400DA502D418676BB01BCD',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'DCCD441D9F0C9E2B8752D1B5215E9759CA4AB1BD',
#         'no_ride',
#         '[13.3152895, 52.514534]',
#         '',
#         '2EA4A3E41B4A3C2C647AC5D6EE98F4C9DC28AD59',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'EBDC3FFA4679B072853DA33477082334018970E5',
#         'no_ride',
#         '[13.315478, 52.5147388]',
#         '',
#         '2EA4A3E41B4A3C2C647AC5D6EE98F4C9DC28AD59',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '9E394B1AEA071C85F062F9A56D54F70F894A3A46',
#         'no_ride',
#         '[13.402203, 52.51138]',
#         '',
#         '2F470CCF7CE4B1A0B71AC011D31ADA1EA00EFB67',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '11440BCEBCE89700B91AE278BA74B78AEC29BCD6',
#         'no_ride',
#         '[13.402255, 52.511295]',
#         '',
#         '2F470CCF7CE4B1A0B71AC011D31ADA1EA00EFB67',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '98A03AD98AF06A27A8530CDD34D7724996147F4E',
#         'no_ride',
#         '[13.4020275, 52.5112521]',
#         '',
#         '2F470CCF7CE4B1A0B71AC011D31ADA1EA00EFB67',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'CCF6297032BF3088A05862E773046377989F3BB0',
#         'no_ride',
#         '[13.411803, 52.512726]',
#         '',
#         '2F4DCDF283DB4BE95F27E9CB8B77AA28514135D5',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'FA776A7FC87C6BB8EF6ED408E02A6A2247A1057B',
#         'no_ride',
#         '[13.4470216, 52.5264798]',
#         '',
#         '2FBE2B02185280C3299287559F004037856B8ECA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'B36F9C53DB2155087E53433FEDA1B39E9636602C',
#         'no_ride',
#         '[13.4470216, 52.5264798]',
#         '',
#         '2FBE2B02185280C3299287559F004037856B8ECA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'BEAE945A783307D9847DB8ACD398E1692AEE54EA',
#         'no_ride',
#         '[13.4470216, 52.5264798]',
#         '',
#         '2FBE2B02185280C3299287559F004037856B8ECA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '5ECC60F5C1A099E9F8611C2DBA66B0CDDAB32A9E',
#         'no_ride',
#         '[13.4470216, 52.5264798]',
#         '',
#         '2FBE2B02185280C3299287559F004037856B8ECA',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '8ADF0D6F92E9849657B445AEA9310BBA31C1D7EB',
#         'no_ride',
#         '[13.36786, 52.508926]',
#         '',
#         '31481117405D3CC7BF45B0E79643E1E55BC623AB',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   '6D37DD90A30415F467728B8BA25A8420583A68E3',
#         'no_ride',
#         '[13.367873, 52.50893]',
#         '',
#         '31481117405D3CC7BF45B0E79643E1E55BC623AB',
#         datetime.datetime(2021, 6, 4, 0, 0),
#         datetime.datetime(2021, 6, 5, 0, 0)),
#     (   'C58901D9AD2F120F3A5E5BA6C257AF18BAED3954',
#         'no_ride',
#         '[13.385623, 52.4848416]',
#         '',
# ...
#         '[13.416444, 52.53611]',
#         '[13.41819, 52.54641]',
#         '',
#         '43C335E07670EC7B7EEDF3C889C33C884E4B4C10',
#         datetime.datetime(2021, 6, 5, 22, 44),
#         datetime.datetime(2021, 6, 5, 23, 5)),
#     (   '9711EF51066099CAF90D9ECA27E2AE617F79AEB7',
#         '[13.402979, 52.537415]',
#         '[13.40328, 52.53746]',
#         '96FD02D0432DA597D6D2561D46D4333322D182F2',
#         '96FD02D0432DA597D6D2561D46D4333322D182F2',
#         datetime.datetime(2021, 6, 5, 23, 0),
#         datetime.datetime(2021, 6, 5, 23, 6)),
#     (   '4BFA40F448C0885C6AE4A3F1BC18EAF0CED20ED5',
#         '[13.3867201, 52.4899408]',
#         '[13.317721, 52.504753]',
#         'C430490F06CD6BBB259EA8F3DEC701C6D474442D',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 33),
#         datetime.datetime(2021, 6, 5, 23, 7)),
#     (   'FBE2BDCDEE2D2BFFF2D55A6DFF046BFC69E7AD92',
#         '[13.392945, 52.527546]',
#         '[13.377325, 52.49981]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 19),
#         datetime.datetime(2021, 6, 5, 23, 8)),
#     (   'F8BEAB353D95558F130BCEC498AA426D89D58016',
#         '[13.407548, 52.509693]',
#         '[13.411889, 52.51075]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 58),
#         datetime.datetime(2021, 6, 5, 23, 8)),
#     (   '8588400847A2E728A9F5E233FE92BF693F71E16C',
#         '[13.40365, 52.537083]',
#         '[13.407161, 52.534943]',
#         '96FD02D0432DA597D6D2561D46D4333322D182F2',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 3),
#         datetime.datetime(2021, 6, 5, 23, 8)),
#     (   '68B2E76432692CF8D5C84D8F3B94FEFAC5570C91',
#         '[13.444333, 52.500343]',
#         '[13.429053, 52.490578]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 51),
#         datetime.datetime(2021, 6, 5, 23, 10)),
#     (   '2DFB9561EDE13FC3E0FE7BCB8863B55CDDD60C7B',
#         '[13.438373, 52.519756]',
#         '[13.440378, 52.523136]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 17, 9),
#         datetime.datetime(2021, 6, 5, 23, 11)),
#     (   '6E196E5A13F295B36FADDDFCA27BE51F43308FCA',
#         '[13.427139, 52.522915]',
#         '[13.4308184, 52.5152187]',
#         'C04242C847B1E8AB4B06D88EB2AB5071C7DCED24',
#         'AFA03F00C37AD276FA4B08010202A00D0016DE48',
#         datetime.datetime(2021, 6, 5, 22, 56),
#         datetime.datetime(2021, 6, 5, 23, 12)),
#     (   '79F77C26B54052576485F69D48778249C4942208',
#         '[13.385482, 52.472095]',
#         '[13.3854, 52.47209]',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         datetime.datetime(2021, 6, 5, 23, 7),
#         datetime.datetime(2021, 6, 5, 23, 14)),
#     (   'BD7C21550649C201FA948815D12CB03A4379FF99',
#         '[13.419449, 52.47336]',
#         '[13.467233, 52.51163]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 33),
#         datetime.datetime(2021, 6, 5, 23, 15)),
#     (   '3F751A890BD6B8B47FB6591D0F6D23E17DD6A9B7',
#         '[13.4390135, 52.489365]',
#         '[13.409076, 52.527942]',
#         '',
#         '0F147ACB94161C37A00BCF849C23108E3CD501C8',
#         datetime.datetime(2021, 6, 5, 22, 49),
#         datetime.datetime(2021, 6, 5, 23, 16)),
#     (   'A0CEED6D70E14167FB776A1960413ECA03DC2A87',
#         '[13.40555, 52.53445]',
#         '[13.385634, 52.520645]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 57),
#         datetime.datetime(2021, 6, 5, 23, 16)),
#     (   'd6a45235-fd66-409c-99ec-89094abf124e',
#         '[13.3854, 52.47209]',
#         '[13.455472, 52.474261]',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         '6E689A1BA6BA6D84E59BE4283862EB1877D21718',
#         datetime.datetime(2021, 6, 5, 20, 23),
#         datetime.datetime(2021, 6, 5, 23, 18)),
#     (   'F747293429A1F4C9C2122F1F4DFCF7BDA65EB005',
#         '[13.3957, 52.48899]',
#         '[13.432273, 52.485245]',
#         '2994AD2BE1AE27F85F0B7CD869342A71A03193E1',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 0),
#         datetime.datetime(2021, 6, 5, 23, 19)),
#     (   'D519642ED4AD49CAADD653A68B78299F708040E8',
#         '[13.3851082, 52.5325434]',
#         '[13.342152, 52.501938]',
#         '653C8889ECF63B2CE101ED6FD15FDD08B1ADEB00',
#         '',
#         datetime.datetime(2021, 6, 5, 21, 50),
#         datetime.datetime(2021, 6, 5, 23, 21)),
#     (   'EFCA972CD47F7DECB434D69FB335F51F275EB900',
#         '[13.3851082, 52.5325434]',
#         '[13.342171, 52.501953]',
#         '653C8889ECF63B2CE101ED6FD15FDD08B1ADEB00',
#         '',
#         datetime.datetime(2021, 6, 5, 21, 50),
#         datetime.datetime(2021, 6, 5, 23, 21)),
#     (   '55d1fcfb-e28e-4bbb-baa5-fdc033180c9c',
#         '[13.290731, 52.5323]',
#         '[13.4368426, 52.5177845]',
#         '',
#         'D6D4DBE0A86E3920963B74EA28E5C53B14E68120',
#         datetime.datetime(2021, 6, 5, 21, 32),
#         datetime.datetime(2021, 6, 5, 23, 21)),
#     (   'FCCB696158A91B9DA430BC95D3DB142A5A7CAEB2',
#         '[13.49867, 52.47923]',
#         '[13.378246, 52.456974]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 20),
#         datetime.datetime(2021, 6, 5, 23, 22)),
#     (   'ace10d76-4629-4f96-a59b-4e8c3b361073',
#         '[13.427339, 52.499508]',
#         '[13.427339, 52.499508]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 22),
#         datetime.datetime(2021, 6, 5, 23, 23)),
#     (   '8B8C18879C327D15384B981EA7917C7BA0C69290',
#         '[13.342767, 52.495965]',
#         '[13.3943939, 52.5323149]',
#         'E4816436351084C8665A14A791C92B9029FFE5A9',
#         '1A4A15EAFABA6A9BD939C26442BB757F477BC3C6',
#         datetime.datetime(2021, 6, 5, 22, 52),
#         datetime.datetime(2021, 6, 5, 23, 25)),
#     (   '3C06727BB0006CB01B459C49BF41331627623F95',
#         '[13.3854, 52.47209]',
#         '[13.377523, 52.48345]',
#         '0CAA0E61854BE1DAC0765CCDA7E542DA1A078E1C',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 8),
#         datetime.datetime(2021, 6, 5, 23, 25)),
#     (   'FB06BA854AF1B2454267771E1A251712F3B414A9',
#         '[13.342571, 52.496063]',
#         '[13.3943939, 52.5323149]',
#         'E4816436351084C8665A14A791C92B9029FFE5A9',
#         '1A4A15EAFABA6A9BD939C26442BB757F477BC3C6',
#         datetime.datetime(2021, 6, 5, 22, 51),
#         datetime.datetime(2021, 6, 5, 23, 26)),
#     (   'BDF79040E0247D8E5181CD7E4C1C8A994DB05DC3',
#         '[13.4664034, 52.5013783]',
#         '[13.437879, 52.488056]',
#         'CF95358ADA76AB412D6A99BB2519AB42BA3FD7F0',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 11),
#         datetime.datetime(2021, 6, 5, 23, 26)),
#     (   '5734AF801E693FE21D57DA4598BFD6326A2E71D6',
#         '[13.3915615, 52.496878]',
#         '[13.426319, 52.501713]',
#         '82EC2EA1D1BC9E9ECAAF536D6C5FFC3BC00A6F4C',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 12),
#         datetime.datetime(2021, 6, 5, 23, 26)),
#     (   'CF2C2357AB153843F30F021032A2B0865FB2CFE4',
#         '[13.3758335, 52.517838]',
#         '[13.3070424, 52.517618]',
#         'C39EF5C70D446232AB2999154624995963330E64',
#         '39780B35A7C2550FCA69DEC3E2DD4C925C21C589',
#         datetime.datetime(2021, 6, 5, 23, 5),
#         datetime.datetime(2021, 6, 5, 23, 29)),
#     (   '4A87B5FA34AE04811C9D8C51F78FB830B00D6428',
#         '[13.440415, 52.483635]',
#         '[13.4318617, 52.4875823]',
#         '',
#         'EE2ACD8B04EDEB34DCA8F8729016AD4BAFEEF8B7',
#         datetime.datetime(2021, 6, 5, 23, 23),
#         datetime.datetime(2021, 6, 5, 23, 30)),
#     (   'd25cda0a-f35e-4a34-af5b-89406280802e',
#         '[13.390732, 52.50544]',
#         '[13.390773, 52.505234]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 28),
#         datetime.datetime(2021, 6, 5, 23, 32)),
#     (   'E289950D036013FF3562E9558A164CF80F9DAEEF',
#         '[13.39326, 52.51744]',
#         '[13.4271705, 52.5229745]',
#         '813890F47E33A57E0C8ABBDCD2783451E4EA60FD',
#         'C04242C847B1E8AB4B06D88EB2AB5071C7DCED24',
#         datetime.datetime(2021, 6, 5, 23, 15),
#         datetime.datetime(2021, 6, 5, 23, 32)),
#     (   '80DA6D42A3E1D90E64C8AB8A3EBA08A050DE3720',
#         '[13.396144, 52.517334]',
#         '[13.4271705, 52.5229745]',
#         '',
#         'C04242C847B1E8AB4B06D88EB2AB5071C7DCED24',
#         datetime.datetime(2021, 6, 5, 23, 16),
#         datetime.datetime(2021, 6, 5, 23, 32)),
#     (   'FB3A95CC7684F21124FC0B8F523E9973C1D73158',
#         '[13.438649, 52.488674]',
#         '[13.422749, 52.49304]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 27),
#         datetime.datetime(2021, 6, 5, 23, 33)),
#     (   'CC4AB90E7BDC2BED908E535FB4B9CFBA939B95A2',
#         '[13.405506, 52.534485]',
#         '[13.384085, 52.52122]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 58),
#         datetime.datetime(2021, 6, 5, 23, 34)),
#     (   '6CCE3EE2F57CAE7F3DE7F1CE7951C57687AACF84',
#         '[13.343557, 52.4859]',
#         '[13.389891, 52.495396]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 13, 2),
#         datetime.datetime(2021, 6, 5, 23, 34)),
#     (   'E604117E978345C94DF52C2C85DF6ED81E4F4138',
#         '[13.43505, 52.50131]',
#         '[13.4429955, 52.4821758]',
#         '4624BDDB665981B2C80DF9FB9DDDD396E77D0FEA',
#         'E71F725330C12D573ECF9102452A33422581EE99',
#         datetime.datetime(2021, 6, 5, 23, 17),
#         datetime.datetime(2021, 6, 5, 23, 34)),
#     (   '5905F421C92F7E9B4D12A3C578AD45D797915AC7',
#         '[13.34237, 52.48678]',
#         '[13.3898735, 52.4954]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 12, 59),
#         datetime.datetime(2021, 6, 5, 23, 35)),
#     (   'C789D1E6A9EFB1C766774050518838B92FE92B1B',
#         '[13.364469, 52.51934]',
#         '[13.401335, 52.526787]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 7),
#         datetime.datetime(2021, 6, 5, 23, 36)),
#     (   '126b0055-6757-48fb-b129-fff05ad27c07',
#         '[13.364538, 52.51944]',
#         '[13.401366, 52.526756]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 8),
#         datetime.datetime(2021, 6, 5, 23, 36)),
#     (   '80B85E71D35F45A2DBC611C6A8867E4FF96F8154',
#         '[13.4074135, 52.534813]',
#         '[13.40328, 52.53746]',
#         '',
#         '96FD02D0432DA597D6D2561D46D4333322D182F2',
#         datetime.datetime(2021, 6, 5, 23, 9),
#         datetime.datetime(2021, 6, 5, 23, 38)),
#     (   '46A3363C234735388954874EEE22B6C973A3857C',
#         '[13.405962, 52.47711]',
#         '[13.414162, 52.481976]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 22, 33),
#         datetime.datetime(2021, 6, 5, 23, 42)),
#     (   '85b5cc24-22ac-4d40-bbe1-fae111945b57',
#         '[13.42299, 52.525898]',
#         '[13.42299, 52.525898]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 43),
#         datetime.datetime(2021, 6, 5, 23, 44)),
#     (   'FF1C0BC034156F431166F7AEF40097B2C709F830',
#         '[13.4016978, 52.5303846]',
#         '[13.39178, 52.49835]',
#         '956B0E81CDF73087BD5352E8E46ABAD30B5DFAB8',
#         '6E390D4E75ABD139E5C5855A14399FEA71CE595F',
#         datetime.datetime(2021, 6, 5, 23, 15),
#         datetime.datetime(2021, 6, 5, 23, 45)),
#     (   '369bbbfc-992f-4451-b206-f702ef5891be',
#         '[13.40069, 52.52202]',
#         '[13.40541, 52.50833]',
#         '82a4b7f8-6760-42bb-85f7-e8e84e6100aa',
#         '4743C6BB8F72009C5D3F42A301F9624FCD40B008',
#         datetime.datetime(2021, 6, 5, 23, 35),
#         datetime.datetime(2021, 6, 5, 23, 47)),
#     (   '09A17BEDB02901892E89551A6AC7CFF0DF4B9A80',
#         '[13.305389, 52.510956]',
#         '[13.327291, 52.529694]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 27),
#         datetime.datetime(2021, 6, 5, 23, 47)),
#     (   '6910A2EF61182C7F75C855993578A04E17C39CFF',
#         '[13.317272, 52.508354]',
#         '[13.328146, 52.527547]',
#         '5FFDBCFCC12390E487838CB796067DC7D6416817',
#         '6ACF1DBE886DB8403E98D2161CF0F25E06943D6C',
#         datetime.datetime(2021, 6, 5, 23, 29),
#         datetime.datetime(2021, 6, 5, 23, 49)),
#     (   'D4CD33CDBB5B5FB4AC2642D9ABE651A5BE22FE57',
#         '[13.449053, 52.50518]',
#         '[13.4420728, 52.5011724]',
#         'EB877F6C8D0310034D417C8E19856045DB312256',
#         '12BDBDC8CB6AFAB60CB472423659A73048FFC159',
#         datetime.datetime(2021, 6, 5, 23, 42),
#         datetime.datetime(2021, 6, 5, 23, 50)),
#     (   '68F9CC110F1C4DE4405876DB0BBF3CE8FE0BC769',
#         '[13.35123, 52.494617]',
#         '[13.35797, 52.485172]',
#         'A71390B036FDFFA161D836AF8ACF71216439DDE5',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 40),
#         datetime.datetime(2021, 6, 5, 23, 50)),
#     (   '74A3A28E005EC04DF3D22D81C8A43E7D65C86255',
#         '[13.342542, 52.496056]',
#         '[13.342767, 52.495965]',
#         'E4816436351084C8665A14A791C92B9029FFE5A9',
#         'E4816436351084C8665A14A791C92B9029FFE5A9',
#         datetime.datetime(2021, 6, 5, 16, 56),
#         datetime.datetime(2021, 6, 5, 23, 50)),
#     (   '1454768B43FF02F059922D2627B0E7BD421939F9',
#         '[13.42192, 52.47755]',
#         '[13.42192, 52.47755]',
#         'CB0DA054670800B4306D9533FAF338A2B227C38D',
#         'CB0DA054670800B4306D9533FAF338A2B227C38D',
#         datetime.datetime(2021, 6, 5, 23, 45),
#         datetime.datetime(2021, 6, 5, 23, 51)),
#     (   '1FD73BA5B3B0F691BA3A46ED483850C3DFBA45A0',
#         '[13.413507, 52.49149]',
#         '[13.4066463, 52.4986318]',
#         '25C9DF0912628FAA2C9E7D915EB45EF8C8CC6070',
#         '1F049CBFFC35D9ACF23F3C478F41F9245921F70C',
#         datetime.datetime(2021, 6, 5, 23, 44),
#         datetime.datetime(2021, 6, 5, 23, 54)),
#     (   '0d1d7866-2100-4809-9eff-049d1215fbc4',
#         '[13.4334188, 52.481732]',
#         '[13.418583, 52.51055]',
#         'AEE637DCC8802EBC23C1EC808DC18C0E24D458F6',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 35),
#         datetime.datetime(2021, 6, 5, 23, 54)),
#     (   '427254158157DBB77182BD9CC8851FD292DEC11C',
#         '[13.399774, 52.531704]',
#         '[13.3661717, 52.5426745]',
#         '',
#         '7308C9EC69DE54848B2C0E75AF5621D50DE131C6',
#         datetime.datetime(2021, 6, 5, 23, 36),
#         datetime.datetime(2021, 6, 5, 23, 54)),
#     (   '518686F834027DB036BED93D59BC3219E831C91E',
#         '[13.441665, 52.52476]',
#         '[13.458481, 52.51044]',
#         '',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 38),
#         datetime.datetime(2021, 6, 5, 23, 55)),
#     (   '57AAE166851A59F4E18243C02581F6C443C88C6B',
#         '[13.3703721, 52.5240026]',
#         '[13.3361564, 52.5233629]',
#         'A7E1FE37645C0907F14B235FE5C8299B5B581FED',
#         '8F70F89E9508484B17886F77C3F4B2CC3C10F527',
#         datetime.datetime(2021, 6, 5, 23, 41),
#         datetime.datetime(2021, 6, 5, 23, 55)),
#     (   'B36F9C53DB2155087E53433FEDA1B39E9636602C',
#         '[13.388133, 52.494034]',
#         '[13.4472039, 52.5215547]',
#         '',
#         '76A4020BE54107E89DE897FB64CE55EB5E5280C7',
#         datetime.datetime(2021, 6, 5, 23, 15),
#         datetime.datetime(2021, 6, 5, 23, 56)),
#     (   'b8e81d28-3e4f-45bf-b3be-da8169fabdc8',
#         '[13.389333, 52.48748]',
#         '[13.445131, 52.4746]',
#         '50879BE8A3BB332DA1C3699A7142D5F4608DA87D',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 7),
#         datetime.datetime(2021, 6, 5, 23, 57)),
#     (   '5ECC60F5C1A099E9F8611C2DBA66B0CDDAB32A9E',
#         '[13.388157, 52.494026]',
#         '[13.4472039, 52.5215547]',
#         '',
#         '76A4020BE54107E89DE897FB64CE55EB5E5280C7',
#         datetime.datetime(2021, 6, 5, 23, 15),
#         datetime.datetime(2021, 6, 5, 23, 57)),
#     (   'F00F2D8EE77650E6BEB944BA2C94333EB74C2C35',
#         '[13.4140706, 52.5081292]',
#         '[13.419205, 52.50136]',
#         'CE079E8D8FCA69AF87DE2D328E93C0FA20F08232',
#         '',
#         datetime.datetime(2021, 6, 5, 23, 49),
#         datetime.datetime(2021, 6, 5, 23, 58)),
#     (   'f0ed3713-5a81-4536-8eed-4c89e626830d',
#         '[13.347375, 52.488297]',
#         '[13.35351, 52.54516]',
#         '',
#         'C9C86A19E1A2F13F7822A3F4792D6B79531B8982',
#         datetime.datetime(2021, 6, 5, 23, 25),
#         datetime.datetime(2021, 6, 5, 23, 59))]

# %%
now = datetime.datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)
# Out:
# Current Time = 11:31:10

# %%
# get all stations of callabike-15.json (for "not all files" exception handling)

station_count = dict()
for day in range(5, 31):
    # for hour in range(start_hour,end_hour):
    date = '2021-' + '06' + '-' + f'{day:02d}'
    for hour in range(0,24):
        for minute in range(0,60):
            # format date and time strings (YYYY-MM-DD and HH-MM), append to directory path
            time_hhmm = f'{hour:02d}' + '-' + f'{minute:02d}'
            DIR = 'json/' + date + '/' + time_hhmm;
            # timestamp of batch of files currently being processed
            datetime_current = datetime.datetime.strptime(date + '-' +  time_hhmm, '%Y-%m-%d-%H-%M')
            # timestamp of previous minute
            datetime_last_minute = datetime_current - datetime.timedelta(minutes=1)
            json_path = DIR+'/callabike-15.json'
            # if given file exists
            if(os.path.exists(json_path)):
                try:
                    # open JSON and write subarray 'items' to array bikes
                    with open(json_path) as bike_json:
                        jsonObject = json.load(bike_json)
                        bike_json.close()
                    bikes = jsonObject['items']
                    if(len(bikes)>0):
                        station_href = str(bikes[0]['area'])
                        # if bike is at an actual station: cut station ID out of area href
                        left_cut_station = station_href.rfind("areas/")+6
                        right_cut_station = station_href.rfind("'}'")-1
                    for bike in bikes:
                        station_href = str(bike['area'])
                        station_id = station_href[:right_cut_station][left_cut_station:]
                        if(station_id in station_count.keys()):
                            station_count[station_id] += 1
                        else:
                            station_count[station_id] = 1
                except JSONDecodeError as e:
                    print("JSONDecodeError")
                except ValueError as e:
                    print("ValueError")
                except KeyError as e:
                    print("KeyError")
                except TypeError as e:
                    print("TypeError")
                except Error as e:
                    print("Error")
pp.pprint(station_count.keys())

# %%
# count Call-A-Bike bike numbers that were rounded up (>= 50) or down (< 50)

over50count = 0
under50count1600 = 0
under50count1500 = 0
notexist = 0

# for all minutes within date
for day in range(5, 30):
    date = '2021-' + '06' + '-' + f'{day:02d}'
    for hour in range(0,24):
        for minute in range(0,60):
            # format date and time strings (YYYY-MM-DD and HH-MM), append to directory path
            time_hhmm = f'{hour:02d}' + '-' + f'{minute:02d}'
            DIR = 'json/' + date + '/' + time_hhmm;
            # if given directory exists
            if(os.path.exists(DIR)):
                # CALL-A-BIKE
                json_path = DIR+'/callabike-0.json'
                if(os.path.exists(json_path)):
                    try:
                        # open JSON and write subarray 'items' to array bikes
                        with open(json_path) as bike_json:
                            jsonObject = json.load(bike_json)
                            bike_json.close()
                        number_bikes = jsonObject['size']
                        number_bikes_modulo = number_bikes % 100
                        if (number_bikes_modulo < 50):
                            under50count1500 += 1
                            if(number_bikes > 1600):
                                under50count1600 += 1
                            else:
                                under50count1500 += 1
                        else:
                            over50count +=1
                    except Error as e:
                        print(e)
                else:
                    notexist += 1
print('Under 50 with over 1600: '+str(under50count1600))
print('Under 50 with under 1600: '+str(under50count1500))
print('Over 50: '+str(over50count))
print('No File: '+str(notexist))
# Out:
# Count 15: 0
# Count 16: 22900
