# %%
import requests
from requests.structures import CaseInsensitiveDict
from pprint import pprint
import json
from getpass import getpass
from mysql.connector import connect, Error
import time

# %%
starttime = time.time()

    for j in range(20):
        lat = "&lat=52.518611"
        lon = "&lon=13.408333"
        radius = "&radius=10000"
        limit = "&limit=100"
        offset = "&offset=" + str(j*100)
        print(offset)
        url = "https://api.deutschebahn.com/flinkster-api-ng/v1/bookingproposals?providernetwork=2" + lat + lon + radius + offset + limit

    headers = CaseInsensitiveDict()
    headers["Accept"] = "application/json"
    headers["Authorization"] = "Bearer 56b6c4f18d92c4869078102e978ec8b9"

    resp = requests.get(url, headers=headers)

    links = resp.json()['items']

    for i in links:
        href = i['area']['href']
        print(href)
    time.sleep(1.0 - ((time.time() - starttime) % 1.0))
# Out:
# &offset=0
# https://api.deutschebahn.com:80/v1/areas/02A01A40044200D9D2CD2AEB0C9E579F01AE8E6B
# https://api.deutschebahn.com:80/v1/areas/02E53D414E6DB10A3632433D657E3E90D23B3C24
# https://api.deutschebahn.com:80/v1/areas/02E53D414E6DB10A3632433D657E3E90D23B3C24
# https://api.deutschebahn.com:80/v1/areas/02E53D414E6DB10A3632433D657E3E90D23B3C24
# https://api.deutschebahn.com:80/v1/areas/043CE57482DAA4E28CB76F2A2473157D20BA01E7
# https://api.deutschebahn.com:80/v1/areas/043CE57482DAA4E28CB76F2A2473157D20BA01E7
# https://api.deutschebahn.com:80/v1/areas/043CE57482DAA4E28CB76F2A2473157D20BA01E7
# https://api.deutschebahn.com:80/v1/areas/04B697D7AB5ED27FC69D14D76E5F43ACC5F95599
# https://api.deutschebahn.com:80/v1/areas/04B697D7AB5ED27FC69D14D76E5F43ACC5F95599
# https://api.deutschebahn.com:80/v1/areas/04B697D7AB5ED27FC69D14D76E5F43ACC5F95599
# https://api.deutschebahn.com:80/v1/areas/04FD4DFD42D9B975C9918F1A407FE44C3C852D3D
# ...

# %%
starttime = time.time()

# loop j from 0 to 19
for j in range(2):
    lat = "&lat=52.518611"
    lon = "&lon=13.408333"
    radius = "&radius=10000"
    limit = "&limit=100"
    # cycle through offset in steps of 100
    offset = "&offset=" + str(j*100)
    print(offset)
    url = "https://api.deutschebahn.com/flinkster-api-ng/v1/bookingproposals?providernetwork=2" + lat + lon + radius + offset + limit

    headers = CaseInsensitiveDict()
    headers["Accept"] = "application/json"
    headers["Authorization"] = "Bearer 56b6c4f18d92c4869078102e978ec8b9"

    resp = requests.get(url, headers=headers)

    links = resp.json()['items']

    for i in links:
        href = i['position']['coordinates']
        print(str(href[1]) + "," + str(href[0]))
        
    # wait 1 second until next request
    # time.sleep(1.0 - ((time.time() - starttime) % 1.0))

# %%
print(resp.content)
# Out:
# b'{"href":"http://api.deutschebahn.com/v1/bookingproposals?providernetwork=2&limit=100&offset=1900&lat=52.518611&lon=13.408333&radius=10000&begin=2021-05-10T12:00:00Z","offset":1900,"limit":100,"size":1823,"items":[],"_links":[{"rel":"self","verb":"GET","href":"http://api.deutschebahn.com/v1/bookingproposals?providernetwork=2&limit=100&offset=1900&lat=52.518611&lon=13.408333&radius=10000&begin=2021-05-10T12:00:00Z"},{"rel":"AppleAppStore","verb":"GET","href":"https://itunes.apple.com/de/app/call-a-bike/id420360589"},{"rel":"GooglePlayStore","verb":"GET","href":"https://play.google.com/store/apps/details?id=de.bahn.callabike&hl=de"}]}'
